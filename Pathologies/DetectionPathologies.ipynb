# %% [markdown]
# **IMPORTS**

# %%
from DeepImageSearch import Index, LoadData, SearchImage

# %% [markdown]
# **LOAD DATA**

# %%
ImagesData = LoadData().from_folder(["AllImages"])

# %%
ImagesData[:30]
# Out:
# ['AllImages\\Alveolisation1.jpg',
#  'AllImages\\Alveolisation10.jpg',
#  'AllImages\\Alveolisation11.jpg',
#  'AllImages\\Alveolisation2.jpg',
#  'AllImages\\Alveolisation3.jpg',
#  'AllImages\\Alveolisation4.jpg',
#  'AllImages\\Alveolisation5.jpg',
#  'AllImages\\Alveolisation6.jpg',
#  'AllImages\\Alveolisation7.jpg',
#  'AllImages\\Alveolisation8.jpg',
#  'AllImages\\Alveolisation9.jpg',
#  'AllImages\\Desquamation1.jpg',
#  'AllImages\\Desquamation10.jpg',
#  'AllImages\\Desquamation2.jpg',
#  'AllImages\\Desquamation3.jpg',
#  'AllImages\\Desquamation4.jpg',
#  'AllImages\\Desquamation5.jpg',
#  'AllImages\\Desquamation6.jpg',
#  'AllImages\\Desquamation7.jpg',
#  'AllImages\\Desquamation8.webp',
#  'AllImages\\Desquamation9.jpg',
#  'AllImages\\Fissure1.jpg',
#  'AllImages\\Fissure10.jpg',
#  'AllImages\\Fissure2.jpg',
#  'AllImages\\Fissure3.jpg',
#  'AllImages\\Fissure4.jpg',
#  'AllImages\\Fissure5.jpg',
#  'AllImages\\Fissure6.jpg',
#  'AllImages\\Fissure7.jpg',
# ...

# %%
Index(ImagesData).Start()
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:06<00:00,  5.06it/s]
# Image Meta Information Saved: [meta-data-files/image_data_features.pkl]
# 31it [00:00, 3442.69it/s]
# Saved the Indexed File:[meta-data-files/image_features_vectors.ann]

# %% [markdown]
# **SEARCH SIMILAR IMAGES**

# %%
SearchImage().get_similar_images(image_path = ImagesData[2], number_of_images = 9)
# Out:
# 1/1 [==============================] - 0s 227ms/step
# {2: 'AllImages\\Alveolisation11.jpg',
#  11: 'AllImages\\Desquamation1.jpg',
#  7: 'AllImages\\Alveolisation6.jpg',
#  17: 'AllImages\\Desquamation6.jpg',
#  16: 'AllImages\\Desquamation5.jpg',
#  24: 'AllImages\\Fissure3.jpg',
#  8: 'AllImages\\Alveolisation7.jpg',
#  28: 'AllImages\\Fissure7.jpg',
#  6: 'AllImages\\Alveolisation5.jpg'}

# %% [markdown]
# **PRINT SIMILAR IMAGES**

# %%
SearchImage().plot_similar_images(image_path = ImagesData[2])
# Out:
# 1/1 [==============================] - 0s 204ms/step
